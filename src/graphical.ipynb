# %% [markdown]
# ## Graphical visualization for plain Trusses
#
# ### Authors:
# * Giancarlo Vanoni
# * Nívea de Abreu
# * Matheus Oliveira

# %% [markdown]
# ## Entrada 1

# %%
from solver import Solver
solve = Solver()
solve.import_file("entrada.xls")
solve.solve_problem()
solve.plot(1e4)
# Out:
# --> Calculating lenght and archs for every element
# --> Obtaining global matrix
# --> Creating every element matrix
# --> Calculating displacements and reactions
# --> Using Gauss-seidel numerical Solution
# --> Calculating Tension, deformation and internal forces
# --> Problem Solved
# --> A file named entrada.txt has been generated with the results
# --> Use 'solve.plot(e)', where 'e' is an factor of conversion, to see graphical results
# /home/matheus1618/Documentos/5_semestre/mecsol/APS4-MecSol/src/solver.py:180: RuntimeWarning: divide by zero encountered in double_scalars
#   rotation =180*np.arctan(self.angs[i,1]/self.angs[i,0])/np.pi,

# %%
with open('outfiles/entrada.txt') as f:
    print(f.read())
# Out:
# Reacoes de apoio [N]
# [[  75.        ]
#  [-224.80529141]
#  [  99.84923205]]
#
# Deslocamentos [m]
# [[ 0.00000000e+00]
#  [-9.50945067e-07]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 1.60575208e-06]
#  [-4.01537818e-06]]
#
# Deformacoes []
# [2.377362667947096e-06, 5.352506938294781e-06, -2.976190476190475e-06]
#
# Forcas internas [N]
# [99.84923205377804, 224.80529140838084, -124.99999999999996]
#
# Tensoes internas [Pa]
# [499246.16026889015, 1124026.457041904, -624999.9999999998]

# %% [markdown]
# ## Entrada 2

# %%
from solver import Solver
solve = Solver()
solve.import_file("entrada_2.xls")
solve.solve_problem()
solve.plot(5)
# Out:
# --> Calculating lenght and archs for every element
# --> Obtaining global matrix
# --> Creating every element matrix
# --> Calculating displacements and reactions
# --> Using Gauss-seidel numerical Solution
# --> Calculating Tension, deformation and internal forces
# --> Problem Solved
# --> A file named entrada_2.txt has been generated with the results
# --> Use 'solve.plot(e)', where 'e' is an factor of conversion, to see graphical results
# /home/matheus1618/Documentos/5_semestre/mecsol/APS4-MecSol/src/solver.py:261: RuntimeWarning: overflow encountered in double_scalars
#   soma += A[i,j]*x0[j,0]
# /home/matheus1618/Documentos/5_semestre/mecsol/APS4-MecSol/src/solver.py:261: RuntimeWarning: invalid value encountered in double_scalars
#   soma += A[i,j]*x0[j,0]

# %%
with open('outfiles/entrada_2.txt') as f:
    print(f.read())
# Out:
# Reacoes de apoio [N]
# [[3900.10306378]
#  [2899.87680356]
#  [1599.86306373]]
#
# Deslocamentos [m]
# [[ 0.        ]
#  [ 0.        ]
#  [ 0.00100461]
#  [-0.00431138]
#  [ 0.0003597 ]
#  [-0.00466275]
#  [ 0.00025966]
#  [-0.00443891]
#  [ 0.00055848]
#  [-0.00463723]
#  [-0.00032433]
#  [-0.00424746]
#  [ 0.00116435]
#  [ 0.        ]]
#
# Deformacoes []
# [-0.0063948891345848745, -0.004492896665471457, -0.003776177143328402, -0.0035280626095955444, -0.0007555075814569316, 0.0007554692457858895, 0.0019111845575389152, -0.0019112562991584552, 0.0018734503403324775, 0.001035278785181747, 0.0031555951295723734]
#
# Forcas internas [N]
# [-6484.321659132044, -4555.729825338075, -3828.9869806778497, -3577.4025651907377, -766.0733549836069, 766.0344831882051, 1937.912473576097, -1937.9852185021864, 1899.6505433420268, 1049.7571589925137, 3199.7261274594425]
#
# Tensoes internas [Pa]
# ...
